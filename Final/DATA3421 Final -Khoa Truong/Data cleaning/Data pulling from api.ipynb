# %%
import pandas as pd
import requests
import json
import time

#Show all columns
pd.set_option('display.max_columns', None)

# %%
##Home Types: Houses, Townhomes, Multi_family, Condos/Co-ops, Lots/Land, Apartments, Manufactured.

##We will look at zillow real estates at these cities:
##Fort Worth
##Arlington
##Irving
##Southlake
##Grapevine
##Grand Prairie
##Dallas
##Plano
##Garland
##Lewisville
##Keller

cities = ['fort worth', 'arlington', 'irving', 'southlake', 'grapevine', 'grand prairie', 'dallas', 
        'plano', 'garland', 'lewisville', 'keller']
state = 'tx'
search_str = list()
for city in cities:
    search_str.append(city + ', ' + state)
print('Search string for all cities:', search_str)
# Out:
# Search string for all cities: ['fort worth, tx', 'arlington, tx', 'irving, tx', 'southlake, tx', 'grapevine, tx', 'grand prairie, tx', 'dallas, tx', 'plano, tx', 'garland, tx', 'lewisville, tx', 'keller, tx']

# %% [markdown]
# ### Data pulling (Using Zillow.com on rapidApi by apimaker)

# %%
##Keep the search below 25 pages, api only uses agent listings
##Keep them in a range price to pull out better data
#Like 0-100000, 100001-200000, 200001-300000, and so forth
#We can get the page number right at the end

#There are house prices at 0 dolloars so we have to remove those instances

# %%
api_key = 'put your key here'

# %%
price_range_list = [(0, 100000), (100001, 200000), (200001, 300000), (300001, 400000),
                    (400001, 500000), (500001, 600000), (600001, 700000), (700001, 800000), (800001, 0)]

##Price range is a tuple of 2 numbers
def properties_getter(home_type, city, price_range):
    ##Using a list to get all of the pages
    all_responses = list()
    
    ##This will pull the data from the first page
    url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"
    min_price = price_range[0]
    max_price = price_range[1]
    if max_price == 0:
        querystring = {"location": city, "home_type": home_type, "minPrice": min_price}
    else:
        querystring = {"location": city, "home_type": home_type, "minPrice": min_price, "maxPrice": max_price}
    headers = {
                "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com",
                "X-RapidAPI-Key": api_key}
    response = requests.request("GET", url, headers=headers, params=querystring)
    
    ##Transform into a json format
    ##If there are no houses existed in the price range, then we return 'None'
    data = response.json()
    all_responses.append(data)
    total_pages = data['totalPages']
    totalResultCount = data['totalResultCount']
    time.sleep(2.5)
    if totalResultCount == 0:
        return "None"
    
    ##Pulling house data from every pages
    ##If total pages > 1 and you want to pull data from second page and so forth
    if total_pages > 1:
        count = 1
        for i in range(1, total_pages):
            if max_price == 0:
                querystring = {"location": city, "page": count + i, "home_type": home_type, 
                               "minPrice": min_price}
            else:
                querystring = {"location": city, "page": count + i, "home_type": home_type, 
                               "minPrice": min_price, "maxPrice": max_price}
            headers = {
                        "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com",
                        "X-RapidAPI-Key": api_key}
            response = requests.request("GET", url, headers=headers, params=querystring)
            data = response.json()
            all_responses.append(data)
            time.sleep(2.5)
    
    return all_responses

# %%
fw2_3 = properties_getter('Houses', 'fort worth, tx', (300001, 400000))
fw2_3
# Out:
# [{'props': [{'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 0.258,
#     'address': '3416 Lawndale Ave, Fort Worth, TX 76133',
#     'daysOnZillow': -1,
#     'price': 365000,
#     'listingDateTime': None,
#     'longitude': -97.366295,
#     'latitude': 32.65684,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29109397',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/b2c7e15411c44b3d9b1e4ab69c5e921b-p_e.jpg',
#     'livingArea': 2215,
#     'bathrooms': 3,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 7187.4,
#     'address': '8033 Moss Rock Dr, Fort Worth, TX 76123',
#     'daysOnZillow': -1,
#     'price': 325000,
#     'listingDateTime': None,
#     'longitude': -97.38204,
#     'latitude': 32.624577,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29246898',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/4bc1317fd102dfadbaae133da7f12168-p_e.jpg',
#     'livingArea': 1919,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 0.266,
#     'address': '6520 Whitman Ave, Fort Worth, TX 76133',
#     'daysOnZillow': -1,
#     'price': 325000,
#     'listingDateTime': None,
#     'longitude': -97.40231,
#     'latitude': 32.651093,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29142996',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/ac34a1a6f8dee2d302fd25ede553dbd1-p_e.jpg',
#     'livingArea': 2074,
#     'bathrooms': 2,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 4748.04,
#     'address': '10956 Colonial Heights Ln, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 349900,
#     'listingDateTime': None,
#     'longitude': -97.42391,
#     'latitude': 32.9228,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '70574914',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/810ca739254aa63d1090dc24ec71410c-p_e.jpg',
#     'livingArea': 2248,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 10367.28,
#     'address': '1501 Vinewood Ct, Fort Worth, TX 76112',
#     'daysOnZillow': -1,
#     'price': 340000,
#     'listingDateTime': None,
#     'longitude': -97.23463,
#     'latitude': 32.756847,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '28969210',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9d1da93d8136aa1f4c361d3fbd60c625-p_e.jpg',
#     'livingArea': 2227,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 0.33,
#     'address': '8017 Ella Young Dr, Lakeside, TX 76135',
#     'daysOnZillow': -1,
#     'price': 390000,
#     'listingDateTime': None,
#     'longitude': -97.46767,
#     'latitude': 32.819,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29257713',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/27972fbfbd2e5ed9e90125a88a3693bf-p_e.jpg',
#     'livingArea': 2208,
#     'bathrooms': 3,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 8407.08,
#     'address': '1220 Dublin Dr, Fort Worth, TX 76134',
#     'daysOnZillow': -1,
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.30912,
#     'latitude': 32.66215,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29000097',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/2c82e03deb6dbbd846b7799a5f7e5099-p_e.jpg',
#     'livingArea': 2661,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 8407.08,
#     'address': '6505 Deer Horn Dr, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 399990,
#     'listingDateTime': None,
#     'longitude': -97.42849,
#     'latitude': 32.87052,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '79953706',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/e63935158a1fdfa24f77ddfa52bbf8c0-p_e.jpg',
#     'livingArea': 2274,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 9496.08,
#     'address': '7501 Monterrey Dr, Fort Worth, TX 76112',
#     'daysOnZillow': -1,
#     'price': 309000,
#     'listingDateTime': None,
#     'longitude': -97.19499,
#     'latitude': 32.75085,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '28948534',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/758fd928c36dcf0e72afb9e931796276-p_e.jpg',
#     'livingArea': 2694,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6011.28,
#     'address': '1221 Brownford Dr, Fort Worth, TX 76114',
#     'daysOnZillow': -1,
#     'price': 350000,
#     'listingDateTime': None,
#     'longitude': None,
#     'latitude': None,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2063137048',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/36f9f47ce17e0e8d1e4b888148aa08c1-p_e.jpg',
#     'livingArea': 2184,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 0.398,
#     'address': '4363 Dove Meadow Ct, Fort Worth, TX 76133',
#     'daysOnZillow': -1,
#     'price': 355000,
#     'listingDateTime': None,
#     'longitude': -97.38528,
#     'latitude': 32.638294,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '28947960',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/af69c0f5183e3ef8e0f87dca4116624b-p_e.jpg',
#     'livingArea': 2189,
#     'bathrooms': 3,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 7666.56,
#     'address': '3148 Rockwell Ln, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 335000,
#     'listingDateTime': None,
#     'longitude': -97.426094,
#     'latitude': 32.923862,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '79938940',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/e42e2f785299842da6fb16ceb833d2cb-p_e.jpg',
#     'livingArea': 2011,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 9016.92,
#     'address': '5425 Waltham Ave, Fort Worth, TX 76133',
#     'daysOnZillow': -1,
#     'price': 359999,
#     'listingDateTime': None,
#     'longitude': -97.38531,
#     'latitude': 32.666885,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29140791',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/b727cfcd9b2ccc0624e5ae621a4aabd4-p_e.jpg',
#     'livingArea': 3073,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 5,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6229,
#     'address': '11344 Live Oak Creek Dr, Fort Worth, TX 76108',
#     'daysOnZillow': -1,
#     'price': 388000,
#     'listingDateTime': None,
#     'longitude': -97.52331,
#     'latitude': 32.763744,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '163323584',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/4c566407bf65b03d38536a7284d458e9-p_e.jpg',
#     'livingArea': 2501,
#     'bathrooms': 4,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6969.6,
#     'address': '950 Caliche Rd, Fort Worth, TX 76108',
#     'daysOnZillow': -1,
#     'price': 380000,
#     'listingDateTime': None,
#     'longitude': -97.51397,
#     'latitude': 32.74913,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '70563100',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/49806e3cd8233291b664f4cec1f41922-p_e.jpg',
#     'livingArea': 2451,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5096.52,
#     'address': '11528 Cactus Springs Dr, Fort Worth, TX 76244',
#     'daysOnZillow': -1,
#     'price': 349000,
#     'listingDateTime': None,
#     'longitude': -97.27407,
#     'latitude': 32.94015,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '61885315',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/3bb27f9734c3d802aa10005dc2033aed-p_e.jpg',
#     'livingArea': 1962,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6534,
#     'address': '5224 Buffalo Gap Trl, Fort Worth, TX 76126',
#     'daysOnZillow': -1,
#     'price': 350000,
#     'listingDateTime': None,
#     'longitude': -97.488396,
#     'latitude': 32.676464,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '89538083',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/1146ca57b030f40bb0ea76286d983604-p_e.jpg',
#     'livingArea': 2072,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6229.08,
#     'address': '5616 Diaz Ave, Fort Worth, TX 76107',
#     'daysOnZillow': -1,
#     'price': 329900,
#     'listingDateTime': None,
#     'longitude': -97.406975,
#     'latitude': 32.727623,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '97717186',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/934df295f27ef613371f489bb412da7c-p_e.jpg',
#     'livingArea': 1793,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 0.346,
#     'address': '9012 Curacao Dr, Fort Worth, TX 76123',
#     'daysOnZillow': -1,
#     'price': 349900,
#     'listingDateTime': None,
#     'longitude': -97.3658,
#     'latitude': 32.612114,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '79954866',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/2bdd05f409d8c40a2af2a811a37fb26d-p_e.jpg',
#     'livingArea': 1700,
#     'bathrooms': 2,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 8058.6,
#     'address': '6140 True Vine Rd, Fort Worth, TX 76123',
#     'daysOnZillow': -1,
#     'price': 395000,
#     'listingDateTime': None,
#     'longitude': -97.4208,
#     'latitude': 32.6171,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2082743692',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/23059235f245cd46bc4159fe6ff521ae-p_e.jpg',
#     'livingArea': 2266,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6534,
#     'address': '5421 Appalachian Way, Fort Worth, TX 76123',
#     'daysOnZillow': -1,
#     'price': 350000,
#     'listingDateTime': None,
#     'longitude': -97.40741,
#     'latitude': 32.6375,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '68970817',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/5e087ff5566c114942f5720e32483178-p_e.jpg',
#     'livingArea': 2079,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': 'Kingston Plan, Parkview Estates',
#     'daysOnZillow': -1,
#     'price': 334990,
#     'listingDateTime': None,
#     'longitude': -97.36915,
#     'latitude': 32.6144,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2063147996',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/207a559730eda6bb7997dc6fa6f0497b-p_e.jpg',
#     'livingArea': 2079,
#     'bathrooms': 2,
#     'lotAreaUnit': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5488.56,
#     'address': '11840 Castleford Way, Crowley, TX 76036',
#     'daysOnZillow': -1,
#     'price': 330000,
#     'listingDateTime': None,
#     'longitude': -97.32934,
#     'latitude': 32.586193,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '336106114',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/3fec73004d455c5e9e48326de7f08300-p_e.jpg',
#     'livingArea': 1677,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 8668.44,
#     'address': '6712 Trilobite Trl, Fort Worth, TX 76137',
#     'daysOnZillow': -1,
#     'price': 400000,
#     'listingDateTime': None,
#     'longitude': -97.305626,
#     'latitude': 32.864613,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29297708',
#     'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/305ebb4264b5023d0683222210811b23-p_e.jpg',
#     'livingArea': 2478,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 7000,
#     'address': '2514 Columbus Ave, Fort Worth, TX 76164',
#     'daysOnZillow': -1,
#     'price': 329000,
#     'listingDateTime': None,
#     'longitude': -97.36457,
#     'latitude': 32.791077,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29086161',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/8168587ea42944cae6896c691f7f795b-p_e.jpg',
#     'livingArea': 2240,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6011.28,
#     'address': '12013 Horseshoe Ridge Dr, Fort Worth, TX 76244',
#     'daysOnZillow': -1,
#     'price': 395000,
#     'listingDateTime': None,
#     'longitude': -97.30456,
#     'latitude': 32.948284,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '89545396',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/f54a0ea14fe2b0c4db99e4c0896880eb-p_e.jpg',
#     'livingArea': 2074,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6359.76,
#     'address': '2614 NW 31st St, Fort Worth, TX 76106',
#     'daysOnZillow': -1,
#     'price': 315000,
#     'listingDateTime': None,
#     'longitude': -97.371956,
#     'latitude': 32.80147,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '97729377',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/8c9a304d25207bf7acf4159c9c9fa9ea-p_e.jpg',
#     'livingArea': 1610,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5096.52,
#     'address': '4769 Jasmine Dr, Fort Worth, TX 76137',
#     'daysOnZillow': -1,
#     'price': 343000,
#     'listingDateTime': None,
#     'longitude': -97.281425,
#     'latitude': 32.869663,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29209446',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/20fd39fc820169aa23b4a1c8f28b9e23-p_e.jpg',
#     'livingArea': 1757,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 7405.2,
#     'address': '6261 Hereford Dr, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 375000,
#     'listingDateTime': None,
#     'longitude': -97.420044,
#     'latitude': 32.86515,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '163422223',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/75a65415a476a7809181ef2247a62101-p_e.jpg',
#     'livingArea': 2184,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 7056.72,
#     'address': '4969 Galley Cir, Fort Worth, TX 76135',
#     'daysOnZillow': -1,
#     'price': 385000,
#     'listingDateTime': None,
#     'longitude': -97.41189,
#     'latitude': 32.82741,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '63415366',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/f7c6a83caf2a1fbf91d5ed444431a858-p_e.jpg',
#     'livingArea': 2725,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 5,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6141.96,
#     'address': '5301 Austin Ridge Dr, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 360000,
#     'listingDateTime': None,
#     'longitude': -97.383316,
#     'latitude': 32.83888,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29125460',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/ada6b9e701acf64f656362be9221e195-p_e.jpg',
#     'livingArea': 2278,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5488.56,
#     'address': '7051 Deer Ridge Dr, Fort Worth, TX 76137',
#     'daysOnZillow': -1,
#     'price': 399900,
#     'listingDateTime': None,
#     'longitude': -97.27319,
#     'latitude': 32.868855,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29313240',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/2d18abca3b157a252e8e12252ec2c57c-p_e.jpg',
#     'livingArea': 2255,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 10628.64,
#     'address': '3620 Minot Ave, Fort Worth, TX 76133',
#     'daysOnZillow': -1,
#     'price': 349900,
#     'listingDateTime': None,
#     'longitude': -97.37011,
#     'latitude': 32.6586,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29109188',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/f1b6628441d02e314313d28ba8612244-p_e.jpg',
#     'livingArea': 2334,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5140.08,
#     'address': '3912 River Birch Rd, Fort Worth, TX 76137',
#     'daysOnZillow': -1,
#     'price': 309000,
#     'listingDateTime': None,
#     'longitude': -97.300545,
#     'latitude': 32.881035,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29244244',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/c867d7448da1d729298671ecc4359f36-p_e.jpg',
#     'livingArea': 1507,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 1,
#     'address': '10236 E Rancho Diego Ln, Crowley, TX 76036',
#     'daysOnZillow': -1,
#     'price': 400000,
#     'listingDateTime': None,
#     'longitude': -97.403824,
#     'latitude': 32.59928,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '58522462',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/6a6a607c2694ac6f54d1569ae71d466e-p_e.jpg',
#     'livingArea': 1796,
#     'bathrooms': 2,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': 'Camden Plan, Parkview Estates',
#     'daysOnZillow': -1,
#     'price': 304990,
#     'listingDateTime': None,
#     'longitude': -97.36915,
#     'latitude': 32.6144,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2063148004',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/845a381999a8d9e188ce12e16461aee4-p_e.jpg',
#     'livingArea': 1532,
#     'bathrooms': 2,
#     'lotAreaUnit': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6011.28,
#     'address': '3829 Byers Ave, Fort Worth, TX 76107',
#     'daysOnZillow': -1,
#     'price': 365000,
#     'listingDateTime': None,
#     'longitude': -97.374435,
#     'latitude': 32.738453,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29070386',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/4be9f7024952c72ddf14924b26c17d88-p_e.jpg',
#     'livingArea': 1310,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 0.269,
#     'address': '3720 Wren Ave, Fort Worth, TX 76133',
#     'daysOnZillow': -1,
#     'price': 375000,
#     'listingDateTime': None,
#     'longitude': -97.37239,
#     'latitude': 32.663994,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29141532',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/933e8e3f756bde73ace6f8e7f8a27cb0-p_e.jpg',
#     'livingArea': 2248,
#     'bathrooms': 2,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 9757.44,
#     'address': '6341 Copperhead Dr, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 349000,
#     'listingDateTime': None,
#     'longitude': -97.43547,
#     'latitude': 32.90918,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '337078714',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/5541acdc85a06002354111fac9db5126-p_e.jpg',
#     'livingArea': 1659,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5447,
#     'address': '8804 Noontide Dr, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 389000,
#     'listingDateTime': None,
#     'longitude': -97.40899,
#     'latitude': 32.88272,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '79948524',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/c1380adc6390f623bd2648bbf42e5fa1-p_e.jpg',
#     'livingArea': 2337,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True}],
#   'resultsPerPage': 40,
#   'totalResultCount': 403,
#   'totalPages': 11},
#  {'props': [{'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 10001.376,
#     'address': '7140 Meadowbrook Dr, Fort Worth, TX 76112',
#     'daysOnZillow': -1,
#     'price': 325000,
#     'listingDateTime': None,
#     'longitude': -97.20519,
#     'latitude': 32.745564,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '28969446',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/31c5dc6ff5ce0acc7833b8b2a1504e20-p_e.jpg',
#     'livingArea': 1410,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6098.4,
#     'address': '2601 Harvest Moon Dr, Fort Worth, TX 76123',
#     'daysOnZillow': -1,
#     'price': 340000,
#     'listingDateTime': None,
#     'longitude': -97.359634,
#     'latitude': 32.626736,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29226840',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/cb67f1d8e44f2a126cd11b160fba6a34-p_e.jpg',
#     'livingArea': 1863,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 7013.16,
#     'address': '2617 Ryan Ave, Fort Worth, TX 76110',
#     'daysOnZillow': -1,
#     'price': 350000,
#     'listingDateTime': None,
#     'longitude': -97.34232,
#     'latitude': 32.71363,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29090613',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/1472a196aa97f8c0a27a1fcc3ac8370a-p_e.jpg',
#     'livingArea': 922,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6098.4,
#     'address': '4525 Lacebark Ln, Fort Worth, TX 76244',
#     'daysOnZillow': -1,
#     'price': 350000,
#     'listingDateTime': None,
#     'longitude': -97.26152,
#     'latitude': 32.963367,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '83793103',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/ff4ebad47c42e9199db969ec5c6ee24e-p_e.jpg',
#     'livingArea': 1868,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5488.56,
#     'address': '3904 Carlsbad Way, Fort Worth, TX 76244',
#     'daysOnZillow': -1,
#     'price': 395000,
#     'listingDateTime': None,
#     'longitude': -97.303185,
#     'latitude': 32.89799,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '61887013',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/8f2edaa4b62c73499574cf2c019a10e5-p_e.jpg',
#     'livingArea': 2492,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 1.011,
#     'address': '1100 Stella Mae Dr, Burleson, TX 76028',
#     'daysOnZillow': -1,
#     'price': 325000,
#     'listingDateTime': None,
#     'longitude': -97.30043,
#     'latitude': 32.594433,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29251331',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/05d3a05ea04078975dcb3f32cf14998d-p_e.jpg',
#     'livingArea': 2046,
#     'bathrooms': 3,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6621.12,
#     'address': '6232 Winnebago Ct, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 395000,
#     'listingDateTime': None,
#     'longitude': -97.419655,
#     'latitude': 32.86912,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '70563776',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/f750beab0af2f93be361878b41cc9fe1-p_e.jpg',
#     'livingArea': 3314,
#     'bathrooms': 4,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 5,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 7405.2,
#     'address': '7112 Brekenridge Dr, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 385000,
#     'listingDateTime': None,
#     'longitude': -97.433304,
#     'latitude': 32.867226,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '61885088',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/c60977a7abaa01b2c9b2ed4308a44974-p_e.jpg',
#     'livingArea': 2277,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 0.341,
#     'address': '3800 Kimberly Ln, Fort Worth, TX 76133',
#     'daysOnZillow': -1,
#     'price': 399000,
#     'listingDateTime': None,
#     'longitude': -97.373924,
#     'latitude': 32.669594,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29141950',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/ac8cfcb7e217be3599f05d21b0380e82-p_e.jpg',
#     'livingArea': 2564,
#     'bathrooms': 2,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': 'Elgin Plan, Parkview Estates',
#     'daysOnZillow': -1,
#     'price': 311990,
#     'listingDateTime': None,
#     'longitude': -97.36915,
#     'latitude': 32.6144,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2063148001',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/acd25fc701238370c94e4c9f1ddd30cc-p_e.jpg',
#     'livingArea': 1653,
#     'bathrooms': 2,
#     'lotAreaUnit': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6011.28,
#     'address': '14141 Rabbit Brush Ln, Haslet, TX 76052',
#     'daysOnZillow': -1,
#     'price': 375000,
#     'listingDateTime': None,
#     'longitude': -97.39526,
#     'latitude': 32.98845,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '245200222',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/68b243c0dcfe4e3739cb607568888981-p_e.jpg',
#     'livingArea': 2149,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 0.257,
#     'address': '9920 Farmers Branch St, Fort Worth, TX 76108',
#     'daysOnZillow': -1,
#     'price': 330000,
#     'listingDateTime': None,
#     'longitude': -97.49268,
#     'latitude': 32.75305,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29152492',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/95064f836b30f8c97d2ae0a6c720ae7e-p_e.jpg',
#     'livingArea': 1862,
#     'bathrooms': 2,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5924.16,
#     'address': '12836 Dorset Dr, Fort Worth, TX 76244',
#     'daysOnZillow': -1,
#     'price': 360000,
#     'listingDateTime': None,
#     'longitude': -97.27137,
#     'latitude': 32.961143,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '79951734',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/1bb7cdff99000943ee5a6b6844dd666c-p_e.jpg',
#     'livingArea': 1673,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 9456.876,
#     'address': '7000 Overhill Rd, Fort Worth, TX 76116',
#     'daysOnZillow': -1,
#     'price': 307000,
#     'listingDateTime': None,
#     'longitude': -97.43601,
#     'latitude': 32.706608,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29079065',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/6d6eeae91d56707719674b9c5787269f-p_e.jpg',
#     'livingArea': 1708,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5706.36,
#     'address': '9016 Nightingale Dr, Fort Worth, TX 76123',
#     'daysOnZillow': -1,
#     'price': 334900,
#     'listingDateTime': None,
#     'longitude': -97.39059,
#     'latitude': 32.610077,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '83804425',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/de5e0010da7bb0af856da068434116e4-p_e.jpg',
#     'livingArea': 1694,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5488.56,
#     'address': '1229 Royal Meadows Trl, Fort Worth, TX 76140',
#     'daysOnZillow': -1,
#     'price': 360000,
#     'listingDateTime': None,
#     'longitude': -97.2921,
#     'latitude': 32.60775,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '337073983',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/64c96e42126bbb15655dbc1dbd674f44-p_e.jpg',
#     'livingArea': 1991,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5183.64,
#     'address': '425 Marble Creek Dr, Fort Worth, TX 76131',
#     'daysOnZillow': -1,
#     'price': 365000,
#     'listingDateTime': None,
#     'longitude': -97.36711,
#     'latitude': 32.92154,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '79928219',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/35df64020094258d2eb49d3283583ec9-p_e.jpg',
#     'livingArea': 2669,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 10802.88,
#     'address': '2208 Marigold Ave, Fort Worth, TX 76111',
#     'daysOnZillow': -1,
#     'price': 370900,
#     'listingDateTime': None,
#     'longitude': -97.314186,
#     'latitude': 32.78269,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29052505',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/0b0610129e54e7555b47f605d9f7c994-p_e.jpg',
#     'livingArea': 1601,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 7840.8,
#     'address': '2141 Carlotta Dr, Fort Worth, TX 76177',
#     'daysOnZillow': -1,
#     'price': 375000,
#     'listingDateTime': None,
#     'longitude': -97.3272,
#     'latitude': 32.920105,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '79923315',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/b5c5780ef9fa729c63c0c86dff9c29d0-p_e.jpg',
#     'livingArea': 1763,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 8755.56,
#     'address': '8121 Salt River Rd, Fort Worth, TX 76137',
#     'daysOnZillow': -1,
#     'price': 399000,
#     'listingDateTime': None,
#     'longitude': -97.276505,
#     'latitude': 32.887585,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29289467',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/32d2d01e456e9b27a02f2a2f9ecfb89c-p_e.jpg',
#     'livingArea': 2434,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6054.84,
#     'address': '1140 Sierra Blanca Dr, Burleson, TX 76028',
#     'daysOnZillow': -1,
#     'price': 375000,
#     'listingDateTime': None,
#     'longitude': -97.29882,
#     'latitude': 32.588215,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '163418242',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/75857939df57dca70e9078a7898250de-p_e.jpg',
#     'livingArea': 2554,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': 'Midland Plan, Parkview Estates',
#     'daysOnZillow': -1,
#     'price': 359990,
#     'listingDateTime': None,
#     'longitude': -97.36915,
#     'latitude': 32.6144,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2063148003',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/c173acd9cf5d38c093494e18e2eb0d1d-p_e.jpg',
#     'livingArea': 2208,
#     'bathrooms': 3,
#     'lotAreaUnit': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 10193.04,
#     'address': '8471 Greylock Ct, Fort Worth, TX 76137',
#     'daysOnZillow': -1,
#     'price': 350000,
#     'listingDateTime': None,
#     'longitude': -97.280075,
#     'latitude': 32.892,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29312834',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9d3d872ff2e41b46639afdb9fbc5c000-p_e.jpg',
#     'livingArea': 1756,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5488.56,
#     'address': '9040 Golden Sunset Trl, Fort Worth, TX 76244',
#     'daysOnZillow': -1,
#     'price': 379900,
#     'listingDateTime': None,
#     'longitude': -97.29527,
#     'latitude': 32.90415,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '70567708',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/3c86d85f5f64b3e9cb98efd13e4c3cbf-p_e.jpg',
#     'livingArea': 2221,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 10410.84,
#     'address': '6416 Wrigley Way, Fort Worth, TX 76133',
#     'daysOnZillow': -1,
#     'price': 370000,
#     'listingDateTime': None,
#     'longitude': -97.39961,
#     'latitude': 32.652267,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '247403720',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/d76da24ef615d00de44cd378cc49a425-p_e.jpg',
#     'livingArea': 2750,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5488.56,
#     'address': '6309 Apalachee Trl, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 344900,
#     'listingDateTime': None,
#     'longitude': -97.42096,
#     'latitude': 32.86847,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '70563793',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/ee01d3526d4cea839019fb3082ae0a55-p_e.jpg',
#     'livingArea': 1637,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 7100.28,
#     'address': '3625 Wayside Ave, Fort Worth, TX 76110',
#     'daysOnZillow': -1,
#     'price': 309000,
#     'listingDateTime': None,
#     'longitude': -97.35147,
#     'latitude': 32.695667,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29008043',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/d8a7606fad70209291c6b4d48edac737-p_e.jpg',
#     'livingArea': 1400,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5488.56,
#     'address': '8825 Noontide Dr, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 379000,
#     'listingDateTime': None,
#     'longitude': -97.409485,
#     'latitude': 32.88342,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '79931385',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/cb9b6fd0c45ee19c7b532ccf91022507-p_e.jpg',
#     'livingArea': 2360,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6011.28,
#     'address': '1236 Sierra Blanca Dr, Burleson, TX 76028',
#     'daysOnZillow': -1,
#     'price': 332400,
#     'listingDateTime': None,
#     'longitude': -97.296646,
#     'latitude': 32.5882,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '70563987',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/d934bd665b78e8f057ef8385e46e5629-p_e.jpg',
#     'livingArea': 1662,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': 'Biloxi Plan, Highlands at Chapel Creek',
#     'daysOnZillow': -1,
#     'price': 341990,
#     'listingDateTime': None,
#     'longitude': -97.50265,
#     'latitude': 32.7394,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2063147992',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/184abda06ad2b971e98450d3e4018608-p_e.jpg',
#     'livingArea': 1733,
#     'bathrooms': 2,
#     'lotAreaUnit': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6098.4,
#     'address': '5740 Crowder Dr, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 329990,
#     'listingDateTime': None,
#     'longitude': -97.42003,
#     'latitude': 32.83822,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '67092841',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/7609e02cb97970c89b0af22ac9109e35-p_e.jpg',
#     'livingArea': 1799,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6094.044,
#     'address': '5329 Kingsknowe Pkwy, Fort Worth, TX 76135',
#     'daysOnZillow': -1,
#     'price': 355000,
#     'listingDateTime': None,
#     'longitude': -97.404305,
#     'latitude': 32.828037,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '54039998',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/85f3ba07f38f58340e0a2781bbf25840-p_e.jpg',
#     'livingArea': 1640,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': 'Natchez Plan, Highlands at Chapel Creek',
#     'daysOnZillow': -1,
#     'price': 344990,
#     'listingDateTime': None,
#     'longitude': -97.50265,
#     'latitude': 32.7394,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2063147993',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/4bbdd603645f875b69c3f71dc40278a6-p_e.jpg',
# ...
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.31619,
#     'latitude': 32.72636,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '97718230',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9a8e0b795aabefc3f244fc334f898707-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': 'Enchanted Bay - The Gables Plan, Enchanted Bay',
#     'daysOnZillow': -1,
#     'price': 319990,
#     'listingDateTime': None,
#     'longitude': -97.23609,
#     'latitude': 32.683815,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2063494361',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/56c7215f37e29981ed4234a3612f5eb8-p_e.jpg',
#     'livingArea': 2013,
#     'bathrooms': 3,
#     'lotAreaUnit': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 10802.88,
#     'address': '2363 Faett Ct, Fort Worth, TX 76119',
#     'daysOnZillow': -1,
#     'price': 375000,
#     'listingDateTime': None,
#     'longitude': -97.298325,
#     'latitude': 32.70088,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29166022',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=32.70087814331055,-97.29832458496094&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=5h5jgcnRzxlvvmVfjxuBZrxAoaQ=',
#     'livingArea': 2025,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': None},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6229.08,
#     'address': '2809 Avenue I, Fort Worth, TX 76105',
#     'daysOnZillow': -1,
#     'price': 330000,
#     'listingDateTime': None,
#     'longitude': -97.2849,
#     'latitude': 32.728283,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '97736514',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9a8e0b795aabefc3f244fc334f898707-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 3920.4,
#     'address': '2869 Brittlebush Dr, Fort Worth, TX 76108',
#     'daysOnZillow': -1,
#     'price': 392910,
#     'listingDateTime': None,
#     'longitude': -97.522026,
#     'latitude': 32.731834,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2066688080',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/2d9e6b44ca5b577cb733c651a8cfc121-p_e.jpg',
#     'livingArea': 2152,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6011.28,
#     'address': '2640 Turtle Dove Dr, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 343999,
#     'listingDateTime': None,
#     'longitude': None,
#     'latitude': None,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2063199379',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/d6fef3baf09d5c0af4c13b644ffa504a-p_e.jpg',
#     'livingArea': 1481,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': 'Desoto Plan, Copper Creek',
#     'daysOnZillow': -1,
#     'price': 365990,
#     'listingDateTime': None,
#     'longitude': -97.35225,
#     'latitude': 32.89832,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2084043504',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/a034b3debcea0a9d6f009059dd88338b-p_e.jpg',
#     'livingArea': 1772,
#     'bathrooms': 2,
#     'lotAreaUnit': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 3920.4,
#     'address': '2840 Brittlebush Dr, Fort Worth, TX 76108',
#     'daysOnZillow': -1,
#     'price': 397642,
#     'listingDateTime': None,
#     'longitude': -97.52237,
#     'latitude': 32.732376,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2066688093',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/2d9e6b44ca5b577cb733c651a8cfc121-p_e.jpg',
#     'livingArea': 2152,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5009.4,
#     'address': '1205 E Hattie St, Fort Worth, TX 76104',
#     'daysOnZillow': -1,
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.31188,
#     'latitude': 32.73817,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '97677539',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9a8e0b795aabefc3f244fc334f898707-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6577.56,
#     'address': '1324 Brownford Dr, Fort Worth, TX 76115',
#     'daysOnZillow': -1,
#     'price': 325000,
#     'listingDateTime': None,
#     'longitude': -97.29487,
#     'latitude': 32.58764,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2064426789',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/e86720e5e92a3d1bb0e5c4724543b3ba-p_e.jpg',
#     'livingArea': 1461,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5009.4,
#     'address': '1605 E Leuda St, Fort Worth, TX 76104',
#     'daysOnZillow': -1,
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.306656,
#     'latitude': 32.736687,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '97693501',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/b1e7184574f8d5bb84dff679a5f73dc5-p_e.jpg',
#     'livingArea': 1799,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5488.56,
#     'address': '2937 Burton Ave, Fort Worth, TX 76105',
#     'daysOnZillow': -1,
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.28212,
#     'latitude': 32.71445,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '28944500',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9a8e0b795aabefc3f244fc334f898707-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': 'Sycamore Landing - Devonhurst II Plan, Sycamore Landing',
#     'daysOnZillow': -1,
#     'price': 348990,
#     'listingDateTime': None,
#     'longitude': -97.35943,
#     'latitude': 32.625107,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2072253578',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/3061a864a1cde7bfe48292f21c54cc88-p_e.jpg',
#     'livingArea': 1947,
#     'bathrooms': 3,
#     'lotAreaUnit': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': 'Sycamore Landing - Asbury Plan, Sycamore Landing',
#     'daysOnZillow': -1,
#     'price': 339990,
#     'listingDateTime': None,
#     'longitude': -97.35943,
#     'latitude': 32.625107,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2072253580',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/a0bebe2bfb2fede0662b33da55c0c931-p_e.jpg',
#     'livingArea': 1704,
#     'bathrooms': 2,
#     'lotAreaUnit': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6011.28,
#     'address': '2621 Turtle Dove Dr, Fort Worth, TX 76179',
#     'daysOnZillow': -1,
#     'price': 353999,
#     'listingDateTime': None,
#     'longitude': None,
#     'latitude': None,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2063199796',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/24a982965c80e96da0f66bd6c51cfe71-p_e.jpg',
#     'livingArea': 1674,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6011.28,
#     'address': '941 E Jessamine St, Fort Worth, TX 76104',
#     'daysOnZillow': -1,
#     'price': 329900,
#     'listingDateTime': None,
#     'longitude': -97.31657,
#     'latitude': 32.7184,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29109893',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/eecc93d448bbba91c348df1a24e93853-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 7492.32,
#     'address': '3521 N Littlejohn Ave, Fort Worth, TX 76105',
#     'daysOnZillow': -1,
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.27396,
#     'latitude': 32.720695,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29123013',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9a8e0b795aabefc3f244fc334f898707-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 3920.4,
#     'address': '2808 Brittlebush Dr, Fort Worth, TX 76108',
#     'daysOnZillow': -1,
#     'price': 390847,
#     'listingDateTime': None,
#     'longitude': -97.52234,
#     'latitude': 32.733288,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2066688084',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/c7578f353444e2b91dec74b55cf9cb4b-p_e.jpg',
#     'livingArea': 2088,
#     'bathrooms': 3,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5009.4,
#     'address': '1111 E Tucker St, Fort Worth, TX 76104',
#     'daysOnZillow': -1,
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.3135,
#     'latitude': 32.739655,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '97697051',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9a8e0b795aabefc3f244fc334f898707-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 6011.28,
#     'address': '1630 E Tucker St, Fort Worth, TX 76104',
#     'daysOnZillow': -1,
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.30502,
#     'latitude': 32.73907,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '97737880',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/25f5f2c1f66f27b7ef80d6a105f61882-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True}],
#   'resultsPerPage': 40,
#   'totalResultCount': 404,
#   'totalPages': 11},
#  {'props': [{'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 0.272,
#     'address': '4118 Ramey Ave, Fort Worth, TX 76105',
#     'daysOnZillow': -1,
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.26368,
#     'latitude': 32.720795,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '29123204',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9a8e0b795aabefc3f244fc334f898707-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'acres',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5009.4,
#     'address': '1301 E Hattie St, Fort Worth, TX 76104',
#     'daysOnZillow': -1,
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.31024,
#     'latitude': 32.738163,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '97721348',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9a8e0b795aabefc3f244fc334f898707-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 5619.24,
#     'address': '1449 E Jefferson Ave, Fort Worth, TX 76104',
#     'daysOnZillow': -1,
#     'price': 310000,
#     'listingDateTime': None,
#     'longitude': -97.30471,
#     'latitude': 32.72474,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '63414748',
#     'listingSubType': {'is_newHome': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9a8e0b795aabefc3f244fc334f898707-p_e.jpg',
#     'livingArea': 1500,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 3,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': 9801,
#     'address': '800 Greer St, Fort Worth, TX 76102',
#     'daysOnZillow': -1,
#     'price': 400000,
#     'listingDateTime': None,
#     'longitude': None,
#     'latitude': None,
#     'contingentListingType': None,
#     'listingStatus': 'FOR_SALE',
#     'zpid': '2068409064',
#     'listingSubType': {'is_FSBA': True},
#     'imgSrc': 'https://photos.zillowstatic.com/fp/6d167cfc64f2ca18112b57b14534492d-p_e.jpg',
#     'livingArea': 1577,
#     'bathrooms': 2,
#     'lotAreaUnit': 'sqft',
#     'country': 'USA',
#     'currency': 'USD',
#     'bedrooms': 4,
#     'hasImage': True}],
#   'resultsPerPage': 40,
#   'totalResultCount': 404,
#   'totalPages': 11}]

# %% [markdown]
# #### Do this for all cities at different price ranges (Houses)

# %%
home_type = "Houses"
all_dfs = list()
for city in search_str:
    for price_range in price_range_list:
        response_city = properties_getter(home_type, city, price_range)
        if response_city != 'None':
            for i in range(len(response_city)):
                df = pd.json_normalize(data = response_city[i]['props'])
                all_dfs.append(df)

# %%
df = pd.concat(all_dfs, axis = 0)
df.reset_index(drop= True, inplace = True)
df
# Out:
#      dateSold   propertyType lotAreaValue  \
# 0        None  SINGLE_FAMILY       7187.4
# 1        None  SINGLE_FAMILY          NaN
# 2        None  SINGLE_FAMILY          NaN
# 3        None  SINGLE_FAMILY          NaN
# 4        None  SINGLE_FAMILY          NaN
# ...       ...            ...          ...
# 3274     None  SINGLE_FAMILY          NaN
# 3275     None  SINGLE_FAMILY          NaN
# 3276     None  SINGLE_FAMILY          NaN
# 3277     None  SINGLE_FAMILY        0.689
# 3278     None  SINGLE_FAMILY        0.689
#
#                                         address  daysOnZillow    price  \
# 0         2510 Dundee Ave, Fort Worth, TX 76106            -1    89900
# 1              Available Soon Plan, Bailey Park            -1        0
# 2     Available Soon Plan, Chisholm Trail Ranch            -1        0
# 3           Available Soon Plan, Risinger Court            -1        0
# 4          Available Soon Plan, Keller Crossing            -1        0
# ...                                         ...           ...      ...
# 3274                Glenmere Plan, Gean Estates            -1   958999
# 3275               Westbrook Plan, Gean Estates            -1   938999
# 3276                  Legacy Plan, Gean Estates            -1   992999
# 3277           2505 Bella Rdg, Keller, TX 76262            -1  2979000
# 3278          2522 Bella Rdg, Roanoke, TX 76262            -1  2695000
#
#      listingDateTime  longitude  latitude contingentListingType listingStatus  \
# 0               None -97.324875  32.79195                  None      FOR_SALE
# 1               None -97.406490  32.88091                  None      FOR_SALE
# 2               None -97.406800  32.60520                  None      FOR_SALE
# 3               None -97.374300  32.61520                  None      FOR_SALE
# 4               None -97.255970  32.93925                  None      FOR_SALE
# ...              ...        ...       ...                   ...           ...
# 3274            None -97.236800  32.94240                  None      FOR_SALE
# 3275            None -97.236800  32.94240                  None      FOR_SALE
# 3276            None -97.236800  32.94240                  None      FOR_SALE
# 3277            None -97.187920  32.95122                  None      FOR_SALE
# 3278            None        NaN       NaN                  None      FOR_SALE
#
#             zpid                                             imgSrc  \
# 0       28965889  https://photos.zillowstatic.com/fp/38411e3b1b6...
# 1     2063150394  https://photos.zillowstatic.com/fp/d45a35d4c93...
# 2     2066907485  https://photos.zillowstatic.com/fp/89d93853dde...
# 3     2067027570  https://photos.zillowstatic.com/fp/c8c6240ccc4...
# 4     2066657560  https://photos.zillowstatic.com/fp/d45a35d4c93...
# ...          ...                                                ...
# 3274  2093819676  https://photos.zillowstatic.com/fp/1836b802b65...
# 3275  2093819679  https://photos.zillowstatic.com/fp/a002b7a0d38...
# 3276  2093819678  https://photos.zillowstatic.com/fp/fde336a1348...
# 3277   337104319  https://maps.googleapis.com/maps/api/staticmap...
# 3278  2072098705  https://photos.zillowstatic.com/fp/e98340f224f...
#
#      livingArea  bathrooms lotAreaUnit country currency bedrooms hasImage  \
# 0         572.0          1        sqft     USA      USD      1.0     True
# 1           NaN          0        None     USA      USD      NaN     True
# 2           NaN          0        None     USA      USD      NaN     True
# 3           NaN          0        None     USA      USD      NaN     True
# 4           NaN          0        None     USA      USD      NaN     True
# ...         ...        ...         ...     ...      ...      ...      ...
# 3274       3603          4        None     USA      USD        3     True
# 3275       3168          3        None     USA      USD        3     True
# 3276       3818          4        None     USA      USD        4     True
# 3277       6683          6       acres     USA      USD        5     None
# 3278       5961          7       acres     USA      USD        5     True
#
#      listingSubType.is_FSBA listingSubType.is_newHome  \
# 0                      True                       NaN
# 1                       NaN                      True
# 2                       NaN                      True
# 3                       NaN                      True
# 4                       NaN                      True
# ...                     ...                       ...
# 3274                    NaN                      True
# 3275                    NaN                      True
# 3276                    NaN                      True
# 3277                    NaN                      True
# 3278                    NaN                      True
#
#      listingSubType.is_openHouse
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 3274                         NaN
# 3275                         NaN
# 3276                         NaN
# 3277                         NaN
# 3278                         NaN
#
# [3279 rows x 23 columns]

# %% [markdown]
# # Using counties instead of cities to get more data

# %%
##These are all for sale houses
##We should look at counties instead of cities to pull out more data!
##North Texas Counties:
##Wise
##Denton
##Collin
##Parker
##Tarrant
##Dallas
##Rockwall
##Kaufman
##Johnson
##Ellis

##We can reuse the same function above: properties_getter

# %%
counties = ['wise', 'denton', 'collin', 'parker', 'tarrant', 'dallas', 'rockwall', 
            'kaufman', 'johnson', 'ellis']

state = 'tx'
search_str2 = list()
for county in counties:
    search_str2.append(county + ' county, ' + state)
print('Search string for all counties:', search_str2)
# Out:
# Search string for all counties: ['wise county, tx', 'denton county, tx', 'collin county, tx', 'parker county, tx', 'tarrant county, tx', 'dallas county, tx', 'rockwall county, tx', 'kaufman county, tx', 'johnson county, tx', 'ellis county, tx']

# %%
##Outer loop goes through each of the counties
#Then we go through each of the price range,
#Then we pull all the data from all pages based on price range and county
##The function properties getter returned a list of dictionaries, and within a dictionary,
##A key named props existed, holding a list of houses on a page, which transformed into json
##Then we dataframed it.

home_type = "Houses"
all_dfs2 = list()
for county in search_str2:
    for price_range in price_range_list:
        response_county = properties_getter(home_type, county, price_range)
        if response_county != 'None':
            for i in range(len(response_county)):
                df2 = pd.json_normalize(data = response_county[i]['props'])
                all_dfs2.append(df2)

# %%
df2 = pd.concat(all_dfs2, axis = 0)
df2.reset_index(drop= True, inplace = True)
df2
# Out:
#       dateSold   propertyType lotAreaValue  \
# 0         None  SINGLE_FAMILY        0.287
# 1         None  SINGLE_FAMILY          0.5
# 2         None  SINGLE_FAMILY          NaN
# 3         None  SINGLE_FAMILY        1.601
# 4         None  SINGLE_FAMILY      7013.16
# ...        ...            ...          ...
# 17964     None  SINGLE_FAMILY       9880.0
# 17965     None  SINGLE_FAMILY        93.28
# 17966     None  SINGLE_FAMILY        1.003
# 17967     None  SINGLE_FAMILY        2.985
# 17968     None  SINGLE_FAMILY        21.86
#
#                                       address priceChange zestimate  \
# 0             210 Boling St, Alvord, TX 76225    -10000.0      None
# 1           307 S Buffalo St, Chico, TX 76431         NaN      None
# 2      Homes Available Soon Plan, Runaway Bay         NaN      None
# 3             4654 Fm 2264, Decatur, TX 76234    -10100.0  162501.0
# 4              212 S Allen St, Boyd, TX 76023    -18000.0  176351.0
# ...                                       ...         ...       ...
# 17964      4750 Brinker St, Prosper, TX 75078         NaN       NaN
# 17965            2955 Fm 667, Italy, TX 76651         1.0       NaN
# 17966   2206 Alyssum Dr, Cedar Hill, TX 75104    -20000.0  924235.0
# 17967     1108 W Lampasas St, Ennis, TX 75119         NaN       NaN
# 17968     1851 Stainback Rd, Ferris, TX 75125         NaN       NaN
#
#                                                   imgSrc    price bedrooms  \
# 0      https://photos.zillowstatic.com/fp/3c58760b725...    99000      2.0
# 1      https://maps.googleapis.com/maps/api/staticmap...    75000      3.0
# 2      https://maps.googleapis.com/maps/api/staticmap...        0      NaN
# 3      https://photos.zillowstatic.com/fp/fa2eac4d679...   164900        5
# 4      https://photos.zillowstatic.com/fp/677bc38643b...   180000        3
# ...                                                  ...      ...      ...
# 17964  https://photos.zillowstatic.com/fp/21306298ff5...  1119990        5
# 17965  https://photos.zillowstatic.com/fp/eade0b23495...  1000000        3
# 17966  https://photos.zillowstatic.com/fp/4f5b3128d76...   955000        4
# 17967  https://photos.zillowstatic.com/fp/2957a4c0688...   899900        2
# 17968  https://photos.zillowstatic.com/fp/abc9265650c...  1579320        0
#
#       contingentListingType  longitude   latitude listingStatus        zpid  \
# 0                      None -97.691216  33.360535      FOR_SALE    78947318
# 1                      None -97.798035  33.291977      FOR_SALE   220098026
# 2                      None  -97.87063   33.17075      FOR_SALE  2062186179
# 3                      None -97.439285  33.164368      FOR_SALE   239956572
# 4                      None   -97.5655  33.076668      FOR_SALE    78938508
# ...                     ...        ...        ...           ...         ...
# 17964                  None  -96.87871   32.24284      FOR_SALE  2058833127
# 17965                  None  -96.83913   32.12741      FOR_SALE    98910632
# 17966                  None -97.011894    32.5438      FOR_SALE    98898464
# 17967                  None -96.635216   32.31849      FOR_SALE    27361004
# 17968                  None  -96.71681  32.537792      FOR_SALE    98891254
#
#       rentZestimate daysOnZillow  bathrooms livingArea country currency  \
# 0            1350.0           -1          2     1080.0     USA      USD
# 1               NaN           11          2     1152.0     USA      USD
# 2            1350.0            7          0        NaN     USA      USD
# 3            2213.0           -1          2       1620     USA      USD
# 4            1863.0           -1          2       1197     USA      USD
# ...             ...          ...        ...        ...     ...      ...
# 17964           NaN           -1          6       4212     USA      USD
# 17965        1450.0           -1          1       1422     USA      USD
# 17966        1424.0          116          4       4398     USA      USD
# 17967        1801.0          270          1       1364     USA      USD
# 17968           NaN           61          0          0     USA      USD
#
#       lotAreaUnit hasImage           variableData.text  variableData.type  \
# 0           acres     True            $10,000 (Mar 11)    PRICE_REDUCTION
# 1           acres     None                         NaN                NaN
# 2            None     None                         NaN                NaN
# 3           acres     True            $10,100 (Mar 14)    PRICE_REDUCTION
# 4            sqft     True            $18,000 (Mar 17)    PRICE_REDUCTION
# ...           ...      ...                         ...                ...
# 17964        sqft     True  Open: Monday - Saturday...         OPEN_HOUSE
# 17965       acres     True           Video Walkthrough  VIDEO_WALKTHROUGH
# 17966       acres     True                         NaN                NaN
# 17967       acres     True                         NaN                NaN
# 17968       acres     True                         NaN                NaN
#
#       listingSubType.is_FSBA variableData newConstructionType      unit  \
# 0                       True          NaN                 NaN       NaN
# 1                       True          NaN                 NaN       NaN
# 2                        NaN          NaN        BUILDER_PLAN  # G00X42
# 3                       True          NaN                 NaN       NaN
# 4                       True          NaN                 NaN       NaN
# ...                      ...          ...                 ...       ...
# 17964                    NaN          NaN        BUILDER_SPEC       NaN
# 17965                   True          NaN                 NaN       NaN
# 17966                    NaN          NaN        BUILDER_SPEC       NaN
# 17967                   True          NaN                 NaN       NaN
# 17968                   True          NaN                 NaN       NaN
#
#       listingSubType.is_newHome listingSubType.is_openHouse  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                          True                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 17964                      True                         NaN
# 17965                       NaN                         NaN
# 17966                      True                         NaN
# 17967                       NaN                         NaN
# 17968                       NaN                         NaN
#
#       listingSubType.is_bankOwned
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ...                           ...
# 17964                         NaN
# 17965                         NaN
# 17966                         NaN
# 17967                         NaN
# 17968                         NaN
#
# [17969 rows x 31 columns]

# %%
df2.to_csv("Raw_API_propertyExtendedSearch/Raw_data_for_sales_houses_counties_March_2023.csv", index = False)
