# %% [markdown]
# # Explanatory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D 
plt.style.use('ggplot')
from matplotlib import gridspec

# %%
df=pd.read_csv("/content/drive/MyDrive/creditcard.csv")

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
### divide the data into 2 based on Class column"
fraud = df[df['Class'] == 1]
normal = df[df['Class'] == 0]

# %%
##length of normal dataset#
len(normal)
# Out:
# 284315

# %%
#length of fraud#
len(fraud)
# Out:
# 492

# %%
## descriptive statistics for the normal transaction
normal.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean    94838.202258       0.008258      -0.006271       0.012171
# std     47484.015786       1.929814       1.636146       1.459429
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54230.000000      -0.917544      -0.599473      -0.884541
# 50%     84711.000000       0.020023       0.064070       0.182158
# 75%    139333.000000       1.316218       0.800446       1.028372
# max    172792.000000       2.454930      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean       -0.007860       0.005453       0.002419       0.009637
# std         1.399333       1.356952       1.329913       1.178812
# min        -5.683171    -113.743307     -26.160506     -31.764946
# ...

# %%
## descriptive statistics for fraud transaction
fraud.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %%
### Find null value
print(df.isnull().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# # Visualization

# %%
corrmat = df.corr()
fig = plt.figure(figsize = (15, 10))
sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()

# %%
### Transaction Times Distribution##
# Split the dataset into fraudulent and non-fraudulent transactions
fraud = df[df['Class'] == 1]
normal = df[df['Class'] == 0]

# Create a histogram of the transaction times for both classes
plt.hist(fraud['Time'], bins=50, alpha=0.5, color='blue', label='Fraud')
plt.hist(normal['Time'], bins=50, alpha=0.5, color='yellow', label='Normal')
plt.xlabel('Transaction Time')
plt.ylabel('Count')
plt.title('Distribution of Transaction Times by Class')
plt.legend()
plt.show()

# %%
#### Amount Distribution with class##
sns.histplot(data=df, x='Amount', hue='Class', bins=50)
# Out:
# <Axes: xlabel='Amount', ylabel='Count'>

# %%
### Amount distribution based on class#
sns.boxplot(data=df, x='Class', y='Amount')
# Out:
# <Axes: xlabel='Class', ylabel='Amount'>

# %%
# Create a histogram for each anomalous feature
anomalous_features = ['V1', 'V2', 'V3', 'V4', 'V5','V6', 'V7', 'V8', 'V9', 'V10','V11', 'V12', 'V13', 'V14', 'V15','V16', 'V17', 'V18', 'V19', 'V20','V21', 'V22', 'V23', 'V24', 'V25','V26', 'V27', 'V28']

# Create a histogram for each anomalous feature
for feature in anomalous_features:
    plt.hist(df[feature][df['Class'] == 1], bins=20, alpha=0.5, label='fraud')
    plt.hist(df[feature][df['Class'] == 0], bins=20, alpha=0.5, label='Normal')
    plt.legend(loc='upper right')
    plt.title('Distribution of Anomalous Feature: ' + feature)
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.show()

# %%
# Create a histogram for each anomalous feature
anomalous_features = df.iloc[:, 1:29].columns

fig, axs = plt.subplots(len(anomalous_features), 1, figsize=(12, len(anomalous_features)*4))

for i, cn in enumerate(anomalous_features):
    sns.histplot(df[cn][df['Class'] == 1], bins=50, ax=axs[i], kde=True, color='red', label='Fraudulent')
    sns.histplot(df[cn][df['Class'] == 0], bins=50, ax=axs[i], kde=True, color='blue', label='Non-fraudulent')
    axs[i].set_xlabel('')
    axs[i].set_title('Histogram of feature: ' + str(cn))
    axs[i].legend()

plt.tight_layout()
plt.show()

# %%
#### Scaling Time and Amount

from sklearn.preprocessing import StandardScaler

# Initialize a StandardScaler object
scaler = StandardScaler()

# Transform the 'Amount' and 'Time' features and assign them to new columns
df['Scaled_amount'] = scaler.fit_transform(df['Amount'].to_numpy().reshape(-1,1))
df['Scaled_time'] = scaler.fit_transform(df['Time'].to_numpy().reshape(-1,1))

# Drop the original 'Amount' and 'Time' columns from the DataFrame
df.drop(['Amount', 'Time'], axis=1, inplace=True)

# Print the first few rows of the DataFrame
print(df.head())
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Class  Scaled_amount  Scaled_time
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

# Separate input features and target
X = df.drop('Class', axis=1)
y = df['Class']

# Downsample the majority class to match the number of samples in the minority class
fraud = df[df['Class'] == 1]
normal = df[df['Class'] == 0].sample(n=1300, random_state=42)

# Combine minority and downsampled majority
downsampled = pd.concat([fraud, normal])

# Split the data into independent and dependent variables
X_train_down, X_test_down, y_train_down, y_test_down = train_test_split(downsampled.drop('Class', axis=1), downsampled['Class'], test_size=0.2, random_state=42)

# Print class distribution of downsampled data
print(y_train_down.value_counts())
# Out:
# 0    1040
# 1     393
# Name: Class, dtype: int64

# %%
from sklearn.decomposition import PCA


# Apply PCA to the downsampled data
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X_train_down.values)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
finalDf = pd.concat([principalDf, y_train_down], axis = 1)

# Visualize the PCA results
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('Two Component PCA on Balanced Data', fontsize = 20)
targets = [0, 1]
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Class'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop("Class", axis=1), df["Class"], test_size=0.2, random_state=42)

# Define the models to be evaluated
models = [("Logistic Regression", LogisticRegression()),
          ("Decision Tree", DecisionTreeClassifier()),
          ("Random Forest", RandomForestClassifier()),
          ("Gradient Boosting", GradientBoostingClassifier()),
          ("AdaBoost", AdaBoostClassifier()),
          ("K-Nearest Neighbors", KNeighborsClassifier()),
          ("Support Vector Machine", SVC())]

# Define an empty dictionary to store the results
results = {}

# Perform 10 runs of each model and store the results
for model_name, model in models:
    acc_scores, prec_scores, rec_scores, f1_scores = [], [], [], []
    for i in range(10):
        # Fit the model to the training data
        model.fit(X_train, y_train)

        # Make predictions on the testing data
        y_pred = model.predict(X_test)

        # Evaluate the model using common evaluation metrics
        acc_scores.append(accuracy_score(y_test, y_pred))
        prec_scores.append(precision_score(y_test, y_pred))
        rec_scores.append(recall_score(y_test, y_pred))
        f1_scores.append(f1_score(y_test, y_pred))

    # Compute the average scores and store them in the results dictionary
    results[model_name] = {
        "Accuracy": sum(acc_scores)/len(acc_scores),
        "Precision": sum(prec_scores)/len(prec_scores),
        "Recall": sum(rec_scores)/len(rec_scores),
        "F1-score": sum(f1_scores)/len(f1_scores)
    }

# Print the results in a table
print("{:<25} {:<10} {:<10} {:<10} {:<10}".format("Model", "Accuracy", "Precision", "Recall", "F1-score"))
for model_name, model_results in results.items():
    print("{:<25} {:.4f}     {:.4f}     {:.4f}     {:.4f}".format(model_name, 
                                                                   model_results["Accuracy"], 
                                                                   model_results["Precision"], 
                                                                   model_results["Recall"], 
                                                                   model_results["F1-score"]))
# Out:
# Model                     Accuracy   Precision  Recall     F1-score
# Logistic Regression       0.9991     0.8636     0.5816     0.6951
# Decision Tree             0.9991     0.7115     0.7908     0.7488
# Random Forest             0.9996     0.9730     0.7714     0.8605
# Gradient Boosting         0.9989     0.7375     0.6020     0.6629
# AdaBoost                  0.9993     0.8554     0.7245     0.7845
# K-Nearest Neighbors       0.9995     0.9383     0.7755     0.8492
# Support Vector Machine    0.9993     0.9531     0.6224     0.7531
