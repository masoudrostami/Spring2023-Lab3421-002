# %% [markdown]
# Questions:
# Answer these questions with graphs and tables and paste your coding here.
# 1.	Show datatype for each variable and summary of the variables?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
startups = pd.read_csv('Startups.csv')

# %%
startups
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
print(startups.dtypes)
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %% [markdown]
# 2.	Show the descriptive statistic for the data frame?

# %%
print(startups['R&D Spend'].describe())
# Out:
# count        50.000000
# mean      73721.615600
# std       45902.256482
# min           0.000000
# 25%       39936.370000
# 50%       73051.080000
# 75%      101602.800000
# max      165349.200000
# Name: R&D Spend, dtype: float64

# %%
print(startups['Administration'].describe())
# Out:
# count        50.000000
# mean     121344.639600
# std       28017.802755
# min       51283.140000
# 25%      103730.875000
# 50%      122699.795000
# 75%      144842.180000
# max      182645.560000
# Name: Administration, dtype: float64

# %%
print(startups['Marketing Spend'].describe())
# Out:
# count        50.000000
# mean     211025.097800
# std      122290.310726
# min           0.000000
# 25%      129300.132500
# 50%      212716.240000
# 75%      299469.085000
# max      471784.100000
# Name: Marketing Spend, dtype: float64

# %%
print(startups['Profit'].describe())
# Out:
# count        50.000000
# mean     112012.639200
# std       40306.180338
# min       14681.400000
# 25%       90138.902500
# 50%      107978.190000
# 75%      139765.977500
# max      192261.830000
# Name: Profit, dtype: float64

# %%
print(startups['State'].describe())
# Out:
# count           50
# unique           3
# top       New York
# freq            17
# Name: State, dtype: object

# %% [markdown]
# 3.	Create histogram and boxplot for independent variables to understand
# the distribution and skewness (mention which one has right or left
# skewness or has normal distribution)?

# %%
startups.hist(column='R&D Spend')
# Out:
# array([[<AxesSubplot: title={'center': 'R&D Spend'}>]], dtype=object)

# %%
startups.hist(column='Administration')
# Out:
# array([[<AxesSubplot: title={'center': 'Administration'}>]], dtype=object)

# %%
startups.hist(column='Marketing Spend')
# Out:
# array([[<AxesSubplot: title={'center': 'Marketing Spend'}>]], dtype=object)

# %%
boxplot = startups.boxplot(column='R&D Spend')

# %%
boxplot = startups.boxplot(column='Administration')

# %%
boxplot = startups.boxplot(column='Marketing Spend')

# %% [markdown]
# * R&D appears to be right-skewed
# * Administration appears to be left-skwed
# * Marketing Spend appears to be normally distributed.

# %% [markdown]
# 4.	Which one of independent variables has the highest variability?

# %%
print(startups['Marketing Spend'].describe())
# Out:
# count        50.000000
# mean     211025.097800
# std      122290.310726
# min           0.000000
# 25%      129300.132500
# 50%      212716.240000
# 75%      299469.085000
# max      471784.100000
# Name: Marketing Spend, dtype: float64

# %% [markdown]
# Marketing Spend due to its high standard deviation and variance when compared to other independent variables.

# %% [markdown]
# 5.	Which one of these independent variables is positively correlated with
# dependent variables?

# %% [markdown]
# R&B Spend is highly positively correlated with dependent variable (profit).

# %% [markdown]
# 6.	Which one of the States has highest profit?

# %%
print(startups['Profit'].describe())
# Out:
# count        50.000000
# mean     112012.639200
# std       40306.180338
# min       14681.400000
# 25%       90138.902500
# 50%      107978.190000
# 75%      139765.977500
# max      192261.830000
# Name: Profit, dtype: float64

# %% [markdown]
# New York

# %% [markdown]
# 7.	Will a company that spends more on marketing perform better (higher
# profit) or a company spends less on marketing?

# %% [markdown]
# A company will perform better if they spend more on marketing compared to a company who spend less on marketing. According to the given data, a company in New York spent the most amount on marketing which led them to have the highest profit among all companies.

# %% [markdown]
# 8.	Create pairwise comparison graph.

# %%
sns.pairplot(startups, hue = 'State', diag_kind = 'kde',
             plot_kws = {'edgecolor': 'k'}, height = 3)

# %%
sns.pairplot(startups, hue = 'Administration', diag_kind = 'kde',
             plot_kws = {'edgecolor': 'k'}, height = 3)

# %%
sns.pairplot(startups, hue = 'R&D Spend', diag_kind = 'kde',
             plot_kws = {'edgecolor': 'k'}, height = 3)

# %%
sns.pairplot(startups, hue = 'Profit', diag_kind = 'kde',
             plot_kws = {'edgecolor': 'k'}, height = 3)

# %%
sns.pairplot(startups, hue = 'Marketing Spend', diag_kind = 'kde',
             plot_kws = {'edgecolor': 'k'}, height = 3)
