# %%
import pandas as pd
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt


print(open('Startups.csv', 'r').read())
# Out:
# R&D Spend,Administration,Marketing Spend,State,Profit
# 165349.2,136897.8,471784.1,New York,192261.83
# 162597.7,151377.59,443898.53,California,191792.06
# 153441.51,101145.55,407934.54,Florida,191050.39
# 144372.41,118671.85,383199.62,New York,182901.99
# 142107.34,91391.77,366168.42,Florida,166187.94
# 131876.9,99814.71,362861.36,New York,156991.12
# 134615.46,147198.87,127716.82,California,156122.51
# 130298.13,145530.06,323876.68,Florida,155752.6
# 120542.52,148718.95,311613.29,New York,152211.77
# 123334.88,108679.17,304981.62,California,149759.96
# 101913.08,110594.11,229160.95,Florida,146121.95
# 100671.96,91790.61,249744.55,California,144259.4
# 93863.75,127320.38,249839.44,Florida,141585.52
# 91992.39,135495.07,252664.93,California,134307.35
# 119943.24,156547.42,256512.92,Florida,132602.65
# 114523.61,122616.84,261776.23,New York,129917.04
# 78013.11,121597.55,264346.06,California,126992.93
# 94657.16,145077.58,282574.31,New York,125370.37
# ...

# %%
data = pd.read_csv('Startups.csv')
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# # 1.Show datatypefor each variable and summary of the variables

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [raw]
# 1) Explain datatype for each vairable and summary of the variable.
#     - R&D SPending: float
#     - Administration: float
#     - Marketing SPend: float
#     - State: object
#     - Profit: float

# %% [markdown]
# # 2.Show the descriptive statistic for the data frame

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [markdown]
# # 3.Create histogram and boxplot for independent variables tounderstand the distribution and skewness

# %%
data.hist(column='R&D Spend', bins=15, grid= False, figsize= (4,4), color='pink')
plt.title('R&D Spend Histogram')
# Out:
# Text(0.5, 1.0, 'R&D Spend Histogram')

# %%
import seaborn as sns
sns.set(style='white')
plt.subplots(figsize=(5,5))
sns.boxplot(data['R&D Spend'],color='plum', width=0.5, orient ='v')
plt.title('R&D Spend Boxplot')
# Out:
# Text(0.5, 1.0, 'R&D Spend Boxplot')

# %%
data.hist(column='Administration', bins=15, grid= False, figsize= (4,4), color='pink')
# Out:
# array([[<AxesSubplot:title={'center':'Administration'}>]], dtype=object)

# %%
sns.set(style='white')
plt.subplots(figsize=(5,5))
sns.boxplot(data['Administration'],color='plum', width=0.5, orient ='v')
plt.title('Administration Boxplot')
# Out:
# Text(0.5, 1.0, 'Administration Boxplot')

# %%
data.hist(column='Marketing Spend', bins=15, grid= False, figsize= (4,4), color='pink')
# Out:
# array([[<AxesSubplot:title={'center':'Marketing Spend'}>]], dtype=object)

# %%
sns.set(style='white')
plt.subplots(figsize=(5,5))
sns.boxplot(data['Marketing Spend'],color='plum', width=0.5, orient ='v')
plt.title('Marketing Spend Boxplot')
# Out:
# Text(0.5, 1.0, 'Marketing Spend Boxplot')

# %%
data.hist(column='Profit', bins=15, grid= False, figsize= (4,4), color='pink')
# Out:
# array([[<AxesSubplot:title={'center':'Profit'}>]], dtype=object)

# %%
sns.set(style='white')
plt.subplots(figsize=(5,5))
sns.boxplot(data['Profit'],color='plum', width=0.5, orient ='v')
plt.title('Profit Boxplot')
# Out:
# Text(0.5, 1.0, 'Profit Boxplot')

# %% [markdown]
# # 4. Which one of independent variables has the highest variability

# %% [markdown]
# To determine the highest variablitiy between the varibles we are using the range calculations. Between the minimum and maximum, market spending has the highest range at 471784.100000.

# %% [markdown]
# # 5. Which one of these independent variables is positively correlated with dependent variables?

# %% [markdown]
# Analyzing the histograms, the independant variable that most correlates with the dependant variable (profit) is the Research and Design (R&D) spending.

# %% [markdown]
# # 6.Which one of the States has highest profit?

# %%
ds= data.iloc[:,3:5]
print (ds)
# Out:
#          State     Profit
# 0     New York  192261.83
# 1   California  191792.06
# 2      Florida  191050.39
# 3     New York  182901.99
# 4      Florida  166187.94
# 5     New York  156991.12
# 6   California  156122.51
# 7      Florida  155752.60
# 8     New York  152211.77
# 9   California  149759.96
# 10     Florida  146121.95
# 11  California  144259.40
# 12     Florida  141585.52
# 13  California  134307.35
# 14     Florida  132602.65
# 15    New York  129917.04
# 16  California  126992.93
# 17    New York  125370.37
# 18     Florida  124266.90
# 19    New York  122776.86
# 20  California  118474.03
# 21    New York  111313.02
# 22     Florida  110352.25
# 23     Florida  108733.99
# 24    New York  108552.04
# 25  California  107404.34
# 26     Florida  105733.54
# 27    New York  105008.31
# 28     Florida  103282.38
# 29    New York  101004.64
# 30     Florida   99937.59
# 31    New York   97483.56
# 32  California   97427.84
# 33     Florida   96778.92
# ...

# %%
data.hist(['Profit'], ['State'], bins=15)
# Out:
# array([[<AxesSubplot:title={'center':'California'}>,
#         <AxesSubplot:title={'center':'Florida'}>],
#        [<AxesSubplot:title={'center':'New York'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# Looking at the graphs above, the state with the most profit is New York

# %% [markdown]
# # 7. Will a company that spends more on marketing perform better (higher profit) or a company spends less on marketing?

# %%
data[['Profit', 'Administration']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data[['Profit', 'R&D Spend']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data[['Profit', 'Marketing Spend']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Looking at the charts created, the companies that made the higher profits spend more on marketing.

# %% [markdown]
# # 8. Create pairwise comparison graph.

# %%
sns.pairplot(data)
